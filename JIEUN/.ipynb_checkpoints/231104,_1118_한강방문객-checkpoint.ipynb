# %% [markdown]
# <a href="https://colab.research.google.com/github/YANG-JIEUN/DataStudy-sat/blob/main/JIEUN/231104%2C_1118_%ED%95%9C%EA%B0%95%EB%B0%A9%EB%AC%B8%EA%B0%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (26.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
# 코랩 사용 시 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1. 데이터 불러오기&결측치 확인

# %% [markdown]
# ##1) 기상 데이터 API 가져오기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from urllib.parse import quote

# %%
# 기상청_지상(종관, ASOS) 일자료 조회서비스 활용을 위한 개인 일반 인증키(Encoding) 저장

key = "fURj5OuFlTtKxCg14GqyGsjoakbzm06eEPKDkzHz8C7fS0vwykajxtBz%2Bv6vrRNg13TTx8CbI1xlRP81fykKeQ%3D%3D"  # 내 인증키

# %%
import ssl
from urllib.request import urlopen
context=ssl.create_default_context()
context.set_ciphers("DEFAULT")

# %%
# 기상관측일자료목록조회
# url : https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=fURj5OuFlTtKxCg14GqyGsjoakbzm06eEPKDkzHz8C7fS0vwykajxtBz%2Bv6vrRNg13TTx8CbI1xlRP81fykKeQ%3D%3D&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20220101&endDt=20221231&stnIds=108
# 인증키 지정 : serviceKey = key
# 출력 행수 : numofRows=365 (2022 1년치)
# page 번호 : pageNo = 1


url = 'https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'+'?serviceKey='+key+'&pageNo=1&numOfRows=365&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20220101&endDt=20221231&stnIds=108'
# stnIds: 지점번호=108이 서울시, api는 서울시 데이터를 옳게 불러왔으므로 이 날씨를 바탕으로 분석을 진행함

# emrList = pd.read_xml(url, xpath='/response/body/items/item')
result = urlopen(url, context=context)
emrList = pd.read_xml(result, xpath='.//item')

emrList.head()
# Out:
#    stnId stnNm          tm  avgTa  minTa  minTaHrmt  maxTa  maxTaHrmt  \
# 0    108    서울  2022-01-01   -4.3  -10.2      710.0    2.3       1544
# 1    108    서울  2022-01-02   -1.3   -5.2     2356.0    3.0       1551
# 2    108    서울  2022-01-03   -1.9   -8.0      714.0    2.5       1542
# 3    108    서울  2022-01-04   -2.5   -5.6     2400.0    1.0       1445
# 4    108    서울  2022-01-05   -2.8   -7.8      634.0    1.9       1518
#
#    mi10MaxRn  mi10MaxRnHrmt  ...  avgM05Te  avgM10Te  avgM15Te  avgM30Te  \
# 0        NaN            NaN  ...       2.7       6.6      10.1      15.1
# 1        NaN            NaN  ...       2.7       6.4      10.0      15.0
# 2        NaN            NaN  ...       2.5       6.2       9.8      14.9
# 3        NaN            NaN  ...       2.5       6.1       9.7      14.8
# 4        NaN            NaN  ...       2.4       5.9       9.5      14.7
#
#    avgM50Te  sumLrgEv  sumSmlEv  n99Rn  \
# 0      17.2       1.3       1.8    0.3
# ...

# %%
# 날짜를 datetime으로 바꿔줌
emrList['tm'] = pd.to_datetime(emrList['tm'])
emrList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 62 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stnId           365 non-null    int64
#  1   stnNm           365 non-null    object
#  2   tm              365 non-null    datetime64[ns]
#  3   avgTa           365 non-null    float64
#  4   minTa           364 non-null    float64
#  5   minTaHrmt       364 non-null    float64
#  6   maxTa           365 non-null    float64
#  7   maxTaHrmt       365 non-null    int64
#  8   mi10MaxRn       94 non-null     float64
#  9   mi10MaxRnHrmt   61 non-null     float64
#  10  hr1MaxRn        94 non-null     float64
#  11  hr1MaxRnHrmt    63 non-null     float64
#  12  sumRnDur        147 non-null    float64
#  13  sumRn           147 non-null    float64
#  14  maxInsWs        365 non-null    float64
#  15  maxInsWsWd      365 non-null    int64
#  16  maxInsWsHrmt    365 non-null    int64
# ...

# %%
# case1: 온도별 한강공원 방문객
## ermList 중 [tm(시간), avgTa(평균 기온), minTa(최저 기온), maxTa(최고 기온)] 컬럼 활용
## case1에 저장하기

case1 = emrList[['tm', 'avgTa', 'minTa', 'maxTa']].copy()
case1.tail()
# Out:
#             tm  avgTa  minTa  maxTa
# 360 2022-12-27   -2.6   -7.3    3.3
# 361 2022-12-28   -3.3   -6.0    0.1
# 362 2022-12-29   -2.9   -7.8    2.1
# 363 2022-12-30   -1.8   -4.4    2.3
# 364 2022-12-31   -1.2   -5.1    2.1

# %%
# case2: 시간과 온도에 따른 한강공원 방문객
## ermList 중 [tm(시간), avgTa(평균 기온), minTa(최저 기온), minTaHrmt(최저 기온 시각), maxTa(최고 기온), maxTaHrmt(최고 기온 시각)] 컬럼 활용
## case2에 저장하기

case2 = emrList[['tm', 'avgTa', 'minTa', 'minTaHrmt', 'maxTa', 'maxTaHrmt']].copy()
case2.head()
# Out:
#           tm  avgTa  minTa  minTaHrmt  maxTa  maxTaHrmt
# 0 2022-01-01   -4.3  -10.2      710.0    2.3       1544
# 1 2022-01-02   -1.3   -5.2     2356.0    3.0       1551
# 2 2022-01-03   -1.9   -8.0      714.0    2.5       1542
# 3 2022-01-04   -2.5   -5.6     2400.0    1.0       1445
# 4 2022-01-05   -2.8   -7.8      634.0    1.9       1518

# %%
# case3: 강수량별 한강공원 방문객
## ermList 중 [tm(시간), avgTa(평균 기온), minTa(최저 기온), maxTa(최고 기온), sumRnDur(강수 계속시간), mi10MaxRn(10분 최다 강수량), mi10MaxRnHrmt(10분 최다 강수량 시각), hr1MaxRn(1시간 최다 강수량), hr1MaxRnHrmt(1시간 최다 강수량 시각), sumRn(일강수량)] 컬럼 활용
## case1에 저장하기

case3 = emrList[['tm', 'avgTa', 'minTa', 'maxTa', 'sumRnDur', 'mi10MaxRn', 'mi10MaxRnHrmt', 'hr1MaxRn', 'hr1MaxRnHrmt', 'sumRn']].copy()
case3.head()
# Out:
#           tm  avgTa  minTa  maxTa  sumRnDur  mi10MaxRn  mi10MaxRnHrmt  \
# 0 2022-01-01   -4.3  -10.2    2.3       NaN        NaN            NaN
# 1 2022-01-02   -1.3   -5.2    3.0      4.17        NaN            NaN
# 2 2022-01-03   -1.9   -8.0    2.5      4.00        NaN            NaN
# 3 2022-01-04   -2.5   -5.6    1.0      0.92        NaN            NaN
# 4 2022-01-05   -2.8   -7.8    1.9       NaN        NaN            NaN
#
#    hr1MaxRn  hr1MaxRnHrmt  sumRn
# 0       NaN           NaN    NaN
# 1       NaN           NaN    0.3
# 2       NaN           NaN    0.0
# 3       NaN           NaN    0.0
# 4       NaN           NaN    NaN

# %% [markdown]
# ##2) 한강공원 주차장 이용현황

# %%
# 한강공원 주차장 이용현황 데이터 불러오기
parking_lot = pd.read_csv('/content/drive/My Drive/스터디/오프라인 3회차 (23.11.4)/한강공원 주차장 일별 이용 현황.csv', encoding='euc-kr')
parking_lot.head()
# Out:
#        지구별        주차장명  주차대수    이용시간          날짜
# 0  PLT-011      잠실1주차장  2497   76141  2023/11/02
# 1  PLT-002  난지1,2,3주차장  1739  114787  2023/11/02
# 2  PLT-007      양화2주차장    25      16  2023/11/02
# 3  PLT-008     여의도5주차장   340  101503  2023/11/02
# 4  PLT-009    반포2,3주차장  3212  157898  2023/11/02

# %%
# 2022 1년치만 확인할 것이므로 날짜를 2022년으로 좁혀보자
parking_lot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34887 entries, 0 to 34886
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지구별     34887 non-null  object
#  1   주차장명    34887 non-null  object
#  2   주차대수    34887 non-null  int64
#  3   이용시간    34887 non-null  int64
#  4   날짜      34887 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ MB

# %%
case1.info()
# 주차장 데이터와 동일하게 날짜가 object 형식임...나중에 datetime으로 바꿔줄 필요가 있어보인다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tm      365 non-null    datetime64[ns]
#  1   avgTa   365 non-null    float64
#  2   minTa   364 non-null    float64
#  3   maxTa   365 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 11.5 KB

# %%
# 날짜를 datetime으로 바꿔주고 2022년 데이터만 확인
parking_lot['날짜'] = pd.to_datetime(parking_lot['날짜'])

# %%
parking_lot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34887 entries, 0 to 34886
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지구별     34887 non-null  object
#  1   주차장명    34887 non-null  object
#  2   주차대수    34887 non-null  int64
#  3   이용시간    34887 non-null  int64
#  4   날짜      34887 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 1.3+ MB

# %%
# 2022년 데이터만 추출&역순으로 출력, 인덱스 초기화
parking_lot_2022 = parking_lot[ parking_lot['날짜'].isin(pd.date_range('2022-01-01', '2022-12-31'))].loc[::-1].reset_index(drop=True)
parking_lot_2022
# Out:
#           지구별      주차장명  주차대수    이용시간         날짜
# 0     PLT-003    망원1주차장   317   19329 2022-01-01
# 1     PLT-009    반포1주차장   901   36061 2022-01-01
# 2     PLT-003  망원2,3주차장  1544  107166 2022-01-01
# 3     PLT-007    양화1주차장   257   15670 2022-01-01
# 4     PLT-008   여의도3주차장   535   38874 2022-01-01
# ...       ...       ...   ...     ...        ...
# 9106  PLT-008   여의도5주차장   129   19176 2022-12-31
# 9107  PLT-008   여의도2주차장   655   54893 2022-12-31
# 9108  PLT-010  잠원2-6주차장  2328  216879 2022-12-31
# 9109  PLT-001    강서1주차장   138    7007 2022-12-31
# 9110  PLT-005    뚝섬2주차장   907   91069 2022-12-31
#
# [9111 rows x 5 columns]

# %% [markdown]
# - 1주차장, 2주차장으로 표기되어있지만 같은 한강공원을 지칭하는 것
# - 지구별로 방문객을 합산하는 것이 분석 목적과 더 부합하다고 판단

# %%
# 지구별로 분류, 똑같은 날짜끼리는 주차대수를 합산하기로 함
parking_lot_2022_sum= parking_lot_2022.groupby(['지구별', '날짜'])['주차대수'].sum().reset_index()
parking_lot_2022_sum
# Out:
#           지구별         날짜  주차대수
# 0     PLT-001 2022-01-01   274
# 1     PLT-001 2022-01-02   208
# 2     PLT-001 2022-01-03   118
# 3     PLT-001 2022-01-04   105
# 4     PLT-001 2022-01-05   103
# ...       ...        ...   ...
# 3934  PLT-011 2022-12-27  3372
# 3935  PLT-011 2022-12-28  3109
# 3936  PLT-011 2022-12-29  3097
# 3937  PLT-011 2022-12-30  2341
# 3938  PLT-011 2022-12-31  1861
#
# [3939 rows x 3 columns]

# %%
# 뭔가 계산이 덜 된 것 같아 PLT-001값을 따로 뽑아보기로 함
parking_lot_2022[(parking_lot_2022['지구별']=='PLT-001') & (parking_lot_2022['날짜']=='2022-01-01')]
# Out:
#        지구별    주차장명  주차대수   이용시간         날짜
# 5  PLT-001  강서1주차장   274  11256 2022-01-01

# %%
# 뭔가 계산이 덜 된 것 같아 PLT-011값을 따로 뽑아보기로 함
parking_lot_2022[(parking_lot_2022['지구별']=='PLT-011') & (parking_lot_2022['날짜']=='2022-12-31')]
# Out:
#           지구별    주차장명  주차대수   이용시간         날짜
# 9088  PLT-011  잠실4주차장  1064  63031 2022-12-31
# 9094  PLT-011  잠실1주차장   797  24777 2022-12-31

# %%
# 놀랍게도 맞는 값이었다....그럼 저 값을 새로운 컬럼으로 만들어보자

# %% [markdown]
# ##3) 서울시 지역별 날씨 현황

# %%
# 따릉이 대여건수 1~6월
seoul = pd.read_csv('/content/drive/My Drive/스터디/오프라인 3회차 (23.11.4)/OBS_AWS_TIM_20231104164010.csv', encoding='euc-kr')

# 필요한 컬럼만 추출: 지점명, 일시, 기온, 강수량, 습도
seoul = seoul[['지점명', '일시', '기온(°C)', '강수량(mm)', '습도(%)']].copy()
seoul
# Out:
#           지점명                일시  기온(°C)  강수량(mm)  습도(%)
# 0       관악(레)  2022-01-01 00:00   -12.0      0.0   46.0
# 1       관악(레)  2022-01-01 01:00   -12.3      0.0   47.0
# 2       관악(레)  2022-01-01 02:00   -12.0      0.0   54.0
# 3       관악(레)  2022-01-01 03:00   -11.5      0.0   54.0
# 4       관악(레)  2022-01-01 04:00   -11.0      0.0   40.0
# ...       ...               ...     ...      ...    ...
# 244754    현충원  2022-12-31 19:00    -3.0      0.0   90.0
# 244755    현충원  2022-12-31 20:00    -3.2      0.0   93.0
# 244756    현충원  2022-12-31 21:00    -3.9      0.0   95.0
# 244757    현충원  2022-12-31 22:00    -3.3      0.0   97.0
# 244758    현충원  2022-12-31 23:00    -3.0      0.0   96.0
#
# [244759 rows x 5 columns]

# %%
# 한강공원 주차장은 뭐가 있나

parking_lot_2022['주차장명'].unique()
# Out:
# array(['망원1주차장', '반포1주차장', '망원2,3주차장', '양화1주차장', '여의도3주차장', '강서1주차장',
#        '이촌1주차장', '광나루3주차장', '뚝섬1주차장', '양화3,4,5주차장', '뚝섬2주차장', '이촌2주차장',
#        '뚝섬3주차장', '반포2,3주차장', '이촌3,4주차장', '뚝섬4주차장', '여의도4주차장',
#        '난지1,2,3주차장', '여의도1주차장', '양화2주차장', '잠원1-6주차장', '잠실1,2,3,4주차장',
#        '여의도5주차장', '여의도2주차장', '광나루1,2주차장', '잠원2-6주차장', '잠원1주차장', '잠실1주차장',
#        '잠실4주차장'], dtype=object)

# %%
# 지역별 관측소 이름

seoul['지점명'].unique()
# Out:
# array(['관악(레)', '강남', '서초', '강동', '송파', '강서', '양천', '도봉', '노원', '동대문',
#        '중랑', '기상청', '마포', '서대문', '광진', '성북', '용산', '은평', '금천', '한강', '중구',
#        '성동', '구로', '강북', '남현', '관악', '영등포 ', '현충원'], dtype=object)

# %% [markdown]
# - 한강공원 주차장 종류: 망원, 반포, 양화, 여의도, 강서, 이촌, 광나루, 뚝섬, 난지, 잠원, 잠실 총 11개
# - 관측소와 한강공원 간 겹치는 지역: 마포(망원, 난지, 양화), 영등포(여의도), 강서(강서), 용산(이촌), 광진(광나루, 뚝섬), 서초(잠원, 반포), 송파(잠실)

# %%
# 관련있는 지역만 뽑아내자
seoul2=seoul[(seoul['지점명']=='마포') | (seoul['지점명']=='영등포') | (seoul['지점명']=='강서') | (seoul['지점명']=='용산') | (seoul['지점명']=='광진') | (seoul['지점명']=='서초') | (seoul['지점명']=='송파')].copy().reset_index()
seoul2.drop(columns = ['index'], inplace=True)
seoul2
# Out:
#       지점명                일시  기온(°C)  강수량(mm)  습도(%)
# 0      서초  2022-01-01 00:00    -6.7      0.0    NaN
# 1      서초  2022-01-01 01:00    -7.3      0.0    NaN
# 2      서초  2022-01-01 02:00    -8.2      0.0    NaN
# 3      서초  2022-01-01 03:00    -9.7      0.0    NaN
# 4      서초  2022-01-01 04:00   -10.0      0.0    NaN
# ...    ..               ...     ...      ...    ...
# 52514  용산  2022-12-31 19:00    -0.4      0.0   66.0
# 52515  용산  2022-12-31 20:00    -1.1      0.0   69.0
# 52516  용산  2022-12-31 21:00    -1.5      0.0   67.0
# 52517  용산  2022-12-31 22:00    -1.6      0.0   71.0
# 52518  용산  2022-12-31 23:00    -1.6      0.0   71.0
#
# [52519 rows x 5 columns]

# %%
# 일시에 시간까지 나와있으므로 컬럼 타입확인
seoul2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52519 entries, 0 to 52518
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지점명      52519 non-null  object
#  1   일시       52519 non-null  object
#  2   기온(°C)   52220 non-null  float64
#  3   강수량(mm)  52079 non-null  float64
#  4   습도(%)    28633 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 2.0+ MB

# %%
# 일시를 datetime으로
seoul2['일시'] = pd.to_datetime(seoul2['일시'])
seoul2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52519 entries, 0 to 52518
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지점명      52519 non-null  object
#  1   일시       52519 non-null  datetime64[ns]
#  2   기온(°C)   52220 non-null  float64
#  3   강수량(mm)  52079 non-null  float64
#  4   습도(%)    28633 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 2.0+ MB

# %%
#
rental1[rental1.duplicated()]
# Out:
#     대여일시 대여건수  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 182  NaN  NaN         NaN         NaN         NaN         NaN
# 183  NaN  NaN         NaN         NaN         NaN         NaN
# 184  NaN  NaN         NaN         NaN         NaN         NaN
# 185  NaN  NaN         NaN         NaN         NaN         NaN
# 186  NaN  NaN         NaN         NaN         NaN         NaN
# 187  NaN  NaN         NaN         NaN         NaN         NaN
# 188  NaN  NaN         NaN         NaN         NaN         NaN
# 189  NaN  NaN         NaN         NaN         NaN         NaN
# 190  NaN  NaN         NaN         NaN         NaN         NaN
# 191  NaN  NaN         NaN         NaN         NaN         NaN
# 192  NaN  NaN         NaN         NaN         NaN         NaN
# 193  NaN  NaN         NaN         NaN         NaN         NaN
# 194  NaN  NaN         NaN         NaN         NaN         NaN
# 195  NaN  NaN         NaN         NaN         NaN         NaN
# ...

# %%
# 결측치 확인
rental1.isnull().sum()
# Out:
# 대여일시           32
# 대여건수           32
# Unnamed: 2    213
# Unnamed: 3    213
# Unnamed: 4    213
# Unnamed: 5    213
# dtype: int64

# %%
# 결측치 행 제거
rental1 = rental1[['대여일시', '대여건수']]
rental2 = rental2[['대여일시', '대여건수']]

# %%
# 결측치 제거
rental1 = rental1.dropna(axis=0)
rental2 = rental2.dropna(axis=0)

# %%
# 해치웠나?
print(rental1.isnull().sum(), rental2.isnull().sum())
# Out:
# 대여일시    0
# 대여건수    0
# dtype: int64 대여일시    0
# 대여건수    0
# dtype: int64

# %%
# 결측치 제거 후 shape 확인
print(rental1.shape, rental2.shape)  # 365로 1년치 데이터가 완성됐다!
# Out:
# (181, 2) (184, 2)

# %%
# 이제 2022 1년치 데이터로 만들어보자
# 위/아래로 합치기 - 행 기준
rental=pd.concat([rental1, rental2], axis = 0)

# rental: 서울시 공공자전거 대여 현황 2022 전체
rental.shape
# Out:
# (365, 2)

# %% [markdown]
# #2. 시각화

# %% [markdown]
# ##1) 기온별 한강공원 방문자수

# %%
parking_lot_2022_sum
# Out:
#           지구별         날짜  주차대수
# 0     PLT-001 2022-01-01   274
# 1     PLT-001 2022-01-02   208
# 2     PLT-001 2022-01-03   118
# 3     PLT-001 2022-01-04   105
# 4     PLT-001 2022-01-05   103
# ...       ...        ...   ...
# 3934  PLT-011 2022-12-27  3372
# 3935  PLT-011 2022-12-28  3109
# 3936  PLT-011 2022-12-29  3097
# 3937  PLT-011 2022-12-30  2341
# 3938  PLT-011 2022-12-31  1861
#
# [3939 rows x 3 columns]

# %%
# case1: 온도별 한강공원 방문객
## ermList 중 [tm(시간), avgTa(평균 기온), minTa(최저 기온), maxTa(최고 기온)] 컬럼
## 컬럼명 바꿔서 합치기

case1 = case1.rename(columns={'tm': '날짜', 'avgTa': '평균 기온', 'minTa': '최저 기온', 'maxTa': '최고 기온'})
case1
# Out:
#             날짜  평균 기온  최저 기온  최고 기온
# 0   2022-01-01   -4.3  -10.2    2.3
# 1   2022-01-02   -1.3   -5.2    3.0
# 2   2022-01-03   -1.9   -8.0    2.5
# 3   2022-01-04   -2.5   -5.6    1.0
# 4   2022-01-05   -2.8   -7.8    1.9
# ..         ...    ...    ...    ...
# 360 2022-12-27   -2.6   -7.3    3.3
# 361 2022-12-28   -3.3   -6.0    0.1
# 362 2022-12-29   -2.9   -7.8    2.1
# 363 2022-12-30   -1.8   -4.4    2.3
# 364 2022-12-31   -1.2   -5.1    2.1
#
# [365 rows x 4 columns]

# %%
# 날짜 기준으로 합치기
parking_lot_2022_date = pd.merge(parking_lot_2022_sum, case1)
parking_lot_2022_date
# Out:
#           지구별         날짜  주차대수  평균 기온  최저 기온  최고 기온
# 0     PLT-001 2022-01-01   274   -4.3  -10.2    2.3
# 1     PLT-002 2022-01-01  1167   -4.3  -10.2    2.3
# 2     PLT-003 2022-01-01  1861   -4.3  -10.2    2.3
# 3     PLT-004 2022-01-01  1182   -4.3  -10.2    2.3
# 4     PLT-005 2022-01-01  2178   -4.3  -10.2    2.3
# ...       ...        ...   ...    ...    ...    ...
# 3934  PLT-006 2022-09-12  1667   23.8   20.3   27.5
# 3935  PLT-007 2022-09-12  2818   23.8   20.3   27.5
# 3936  PLT-008 2022-09-12  9500   23.8   20.3   27.5
# 3937  PLT-010 2022-09-12  4806   23.8   20.3   27.5
# 3938  PLT-011 2022-09-12  3346   23.8   20.3   27.5
#
# [3939 rows x 6 columns]

# %%
# 날짜별 평균
parking_lot_2022_mean = parking_lot_2022.groupby('날짜')['주차대수'].mean().reset_index()
parking_lot_2022_mean = parking_lot_2022_mean.rename(columns={'주차대수': '평균주차대수'})
parking_lot_2022_mean
# parking_lot_2022_date = pd.merge(parking_lot_2022_date, parking_lot_2022_mean)
# parking_lot_2022_date
# Out:
#             날짜      평균주차대수
# 0   2022-01-01  885.120000
# 1   2022-01-02  709.280000
# 2   2022-01-03  625.120000
# 3   2022-01-04  646.720000
# 4   2022-01-05  640.960000
# ..         ...         ...
# 358 2022-12-27  584.037037
# 359 2022-12-28  548.666667
# 360 2022-12-29  580.074074
# 361 2022-12-30  592.037037
# 362 2022-12-31  685.888889
#
# [363 rows x 2 columns]

# %%
# 날짜별 평균주차대수
# 앞서 데이터프레임을 만들 때, 별도의 지구별 분류 없이 날짜별로 주차대수의 평균을 구함

plt.plot(parking_lot_2022_mean['날짜'],parking_lot_2022_mean['평균주차대수'])
plt.show()

# %% [markdown]
# - 평균주차대수가 가장 높은 계절은 봄, 가장 낮은 시즌은 겨울임을 알 수 있음
# - 예상대로 겨울에 가까워질수록 방문객 수가 줄어든다는 것을 알 수 있었다

# %%
# 방문자수가 가장 높은 달과 낮은 달을 확인하고, 그날 날씨를 알아보자
print(parking_lot_2022_mean.loc[parking_lot_2022_mean['평균주차대수'].idxmax()])
print(parking_lot_2022_mean.loc[parking_lot_2022_mean['평균주차대수'].idxmin()])
# Out:
# 날짜        2022-04-10 00:00:00
# 평균주차대수                2118.36
# Name: 99, dtype: object
# 날짜        2022-08-10 00:00:00
# 평균주차대수             113.857143
# Name: 221, dtype: object

# %%
# 4월 10일의 날씨
print(case1[(case1['날짜']=='2022-04-10')])

# 8월 10일의 날씨
print(case1[(case1['날짜']=='2022-08-10')])
# Out:
#            날짜  평균 기온  최저 기온  최고 기온
# 99 2022-04-10   18.2   12.7   25.1
#             날짜  평균 기온  최저 기온  최고 기온
# 221 2022-08-10   24.7   21.4   28.8

# %%
# 주차대수가 최저라고 하기엔 어딘가 납득이 안되는 날씨....전체를 끌고와보자
case3[(case3['tm']=='2022-08-10')] # 강수량 포함 데이터
# Out:
#             tm  avgTa  minTa  maxTa  sumRnDur  mi10MaxRn  mi10MaxRnHrmt  \
# 221 2022-08-10   24.7   21.4   28.8       6.5        2.2        -2356.0
#
#      hr1MaxRn  hr1MaxRnHrmt  sumRn
# 221      10.0       -2340.0    7.6

# %% [markdown]
# 최대, 최저 온도는 30도 내로, 8월 치곤 선선한 날씨였지만 **강수량을 확인하니 비가 6시간 넘게 지속되는 등 긴 시간동안 비가 왔음**을 알 수 있음

# %% [markdown]
# ## 2) 서울시 상세 지역별 비교

# %%
plt.plot(parking_lot_2022_mean['날짜'],parking_lot_2022_mean['평균주차대수'])
plt.show()

# %% [markdown]
# # 요약
# 1. 날씨에 따른 한강 방문객을 확인하고자 공공자전거 대여 데이터와 한강공원 주차장 데이터를 구했으나, 공공자전거 대여 데이터의 경우 대여날짜와 건수만 나와있어 적합하지 않다고 판단, **주차장 데이터로만 분석을 진행함.**
# 2.한강공원 주차대수 날짜별 평균과 서울시 전체 날씨 데이터를 놓고 봤을 때, 겨울에 전반적으로 주차대수가 감소하고 날씨가 따뜻해지는 봄~가을까지 이용객이 많았음
# 3. 가장 주차대수가 적었던 날은 가장 더운 날일 것이라고 예상했으나, 오히려 비가 오는 날에 평균 주차대수가 적었음

# %% [markdown]
# # 추가로 진행할 분석
# 1. 주차대수가 많은 한강공원의 경우, 한강공원 조성이 다른 곳들과 어떻게 다른가?
# 2. 주차대수가 많은 날짜의 경우 근처에서 어떤 행사가 진행되었나?
# 3. 공공자전거 대여 현황 데이터 API 불러와서 지점별 확인
#   → 한강공원은 별도의 자전거 대여소 운영하므로 정확한 분석을 진행하기 어렵다고 판단
# 4. 벚꽃 개화시기에 따른 방문자 수 변화?
